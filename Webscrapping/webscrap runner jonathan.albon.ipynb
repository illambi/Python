# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
# base_url = 'https://www.atptour.com/es/players/roger-federer/f324/rankings-history' -- code 403
# base_url = 'https://itra.run/RunnerSpace/RaceResults/JORNET-BURGADA.Kilian/2704' -- code 403
# base_url = 'https://www.atptour.com/es/players/roger-federer/f324/player-stats' -- code 403
base_url = 'https://utmb.world/es/runner/527631.jonathan.albon'

# %%
res = requests.get(base_url)
soup = BeautifulSoup(res.content, 'lxml') #, 'html.parser')

res.status_code
# Out:
# 200

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/><meta content="es" property="og:locale"/><meta content="general" name="rating"/><link href="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/default-favicon?_a=ATADJcW0" rel="shortcut icon"/><title>Jonathan ALBON - Sus resultados y su UTMB® Index</title><meta content="Jonathan ALBON - Sus resultados y su UTMB® Index" name="title"/><meta content="El UTMB®Index de Jonathan ALBON es 942. Corre para el equipo -. Terminó 3º en la The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short. Comprueba sus resultados y su índice UTMB®." name="description"/><meta content="Jonathan ALBON, -, The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short, UTMB® Index, Trail, Resultados" name="keywords"/><meta content="Jonathan ALBON - Sus resultados y su UTMB® Index" name="og:title"/><meta content="El UTMB®Index de Jonathan ALBON es 942. Corre para el equipo -. Terminó 3º en la The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short. Comprueba sus resultados y su índice UTMB®." name="og:description"/><meta content="" name="og:url"/><meta content="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/worldseries/Members/Admin/ALBON.JONATHAN_baskht?_a=ATADJcW0" name="og:image"/><meta content="website" name="og:type"/><meta content="@UTMBWorldSeries" name="twitter:site"/><meta content="" name="twitter:url"/><meta content="Jonathan ALBON - Sus resultados y su UTMB® Index" name="twitter:title"/><meta content="El UTMB®Index de Jonathan ALBON es 942. Corre para el equipo -. Terminó 3º en la The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short. Comprueba sus resultados y su índice UTMB®." name="twitter:description"/><meta content="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/worldseries/Members/Admin/ALBON.JONATHAN_baskht?_a=ATADJcW0" name="twitter:image"/><meta content="summary_large_image" name="twitter:card"/><meta content="index,follow" name="robots"/><meta content="index,follow" name="googlebot"/><link href="https://utmb.world/runner/527631.jonathan.albon" hreflang="en" rel="alternate"/><link href="https://utmb.world/fr/runner/527631.jonathan.albon" hreflang="fr" rel="alternate"/><link href="https://utmb.world/es/runner/527631.jonathan.albon" hreflang="es" rel="alternate"/><link href="https://utmb.world/it/runner/527631.jonathan.albon" hreflang="it" rel="alternate"/><link href="https://utmb.world/runner/527631.jonathan.albon" hreflang="x-default" rel="alternate"/><link href="" rel="canonical"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","url":"https://utmb.world","name":"UTMB® World Series","sameAs":["https://www.facebook.com/UTMBWorldSeries","https://www.instagram.com/utmbworldseries/","https://twitter.com/utmbworldseries","https://www.youtube.com/c/UTMBWorldSeries","https://www.strava.com/clubs/ultra-trail%C2%AE-world-tour-228759?"]}</script><meta content="29" name="next-head-count"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://accounts.utmb.world" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://static.hotjar.com" rel="preconnect"/><link href="https://res.cloudinary.com" rel="preconnect"/><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link as="style" href="/_next/static/css/b16686d52b603469.css" rel="preload"/><link data-n-g="" href="/_next/static/css/b16686d52b603469.css" rel="stylesheet"/><link as="style" href="/_next/static/css/350e1f6dc7376768.css" rel="preload"/><link data-n-p="" href="/_next/static/css/350e1f6dc73767 ...

# %%
carreras = soup.find_all('div', attrs={"class":'my-table_row__nlm_j'})
carreras
# Out:
# [<div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">05/11/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/36226.theamazingthailandwmrcchiangmaiwmtrc2021short.2022">The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-th flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">38 KM<br/>2425 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:13:05</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">3 / 50</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">3 / 30</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">26/08/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/141.utmb-montblancccc-.2022">UTMB® Mont Blanc 2022 - CCC®</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-fr flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="100K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_118,w_400/if_end/e_blur/v1/Common/categories/100K?_a=ATADJcW0");background-position:left'/><noscript><img alt="100K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/100K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">99.1 KM<br/>5990 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">10:16:26</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">2 / 1727</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">2 / 1480</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">06/08/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/34800.strandafjordtrailrace25kgtws.2022">Stranda Fjord Trail Race 2022 - 25k gtws</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-no flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="20K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/20K?_a=ATADJcW0");background-position:left'/><noscript><img alt="20K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/20K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">25 KM<br/>1700 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">02:24:02</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 470</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 298</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">26/06/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/432.marathondumont-blanc42kmdumont-blanc.2022">Marathon du Mont-Blanc 2022 - 42 Km du Mont-Blanc</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-fr flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">44.4 KM<br/>2500 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:35:20</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 2096</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 1682</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">29/05/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/1523.greenweezmaxi-racemarathonrace.2022">Greenweez MaXi-Race 2022 - Marathon Race</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-fr flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">40 KM<br/>3000 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:29:25</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 304</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 249</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">24/10/2021</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/78.festivaldestempliersgrandtraildestempliers.2021">Festival Des Templiers 2021 - Grand Trail Des Templiers</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-fr flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="100K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_118,w_400/if_end/e_blur/v1/Common/categories/100K?_a=ATADJcW0");background-position:left'/><noscript><img alt="100K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/100K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">81.2 KM<br/>3539 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">06:32:19</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 1944</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 1762</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">02/10/2021</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/17007.salomonultrapirineumaratopirineu42k.2021">Salomon Ultra Pirineu 2021 - Marató Pirineu 42k</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-es flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">42.1 KM<br/>2804 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:34:08</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 923</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 816</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">25/08/2021</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/2280.utmb-occ.2021">UTMB® 2021 - OCC</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-fr flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">56.3 KM<br/>3476 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">05:02:57</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 1359</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 1094</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">07/08/2021</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/3900.fjallmaratonveckanarefjallenkiafjallmaraton45k.2021">Fjällmaratonveckan Årefjällen 2021 - KIA Fjällmaraton 45k</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-se flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">45 KM<br/>2100 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:38:07</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">1 / 461</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">1 / 314</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>,
#  <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">16/11/2019</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/1700.k42adventuremarathonargentinawmrachampvillalaangostura.2019">K42 ADVENTURE MARATHON ARGENTINA 2019 - WMRA Champ Villa La Angostura</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-ar flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">41.5 KM<br/>2184 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:22:10</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">4 / 163</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">4 / 88</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>]

# %%
carreras[0]
# Out:
# <div class="my-table_row__nlm_j"><div class="my-table_cell__z__zN col-1" style="min-height:5rem">05/11/2022</div><div class="my-table_cell__z__zN col-4" style="min-height:5rem"><a class="link_link__96ppl" href="/utmb-index/races/36226.theamazingthailandwmrcchiangmaiwmtrc2021short.2022">The Amazing Thailand WMRC 2022 - Chiangmai wmtrc 2021 short</a></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="país" style="min-height:5rem"><span class="results-table_flag__nNg2c fi fi-th flag_flag__vI17O"></span></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Cat." style="min-height:5rem"><div class="pi-category-logo_container__1zLvC"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="50K" data-nimg="fill" decoding="async" src="..." style='position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left;filter:blur(20px);background-size:contain;background-image:url("https://res.cloudinary.com/utmb-world/image/upload/if_w_gt_400/c_scale,h_129,w_400/if_end/e_blur/v1/Common/categories/50K?_a=ATADJcW0");background-position:left'/><noscript><img alt="50K" data-nimg="fill" decoding="async" loading="lazy" src="https://res.cloudinary.com/utmb-world/image/upload/q_auto/f_auto/c_fill,g_auto/if_w_gt_1920/c_scale,w_1920/if_end/v1/Common/categories/50K?_a=ATADJcW0" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:contain;object-position:left"/></noscript></span></div></div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Distancia" style="min-height:5rem">38 KM<br/>2425 M+</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Tiempo" style="min-height:5rem">03:13:05</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="clasificación" style="min-height:5rem">3 / 50</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Género" style="min-height:5rem">3 / 30</div><div class="my-table_cell__z__zN col-1 my-table_hide_mobile__t6aJD" data-label="Puntuación" style="min-height:5rem"><div class="placeholder_skeleton__Icj1o" style="width:50%;height:3rem"></div></div><div class="my-table_show_more__YgJrn"><div class="my-table_dot__g4nQD"></div></div><div class="my-table_break_line_mobile__B8wba"></div></div>

# %%
carreras[0]
titulos = [i.text for i in titulos]

# %%
x = []
y = []
xG = []
result = []
team = []
player = []
shotType = []
minute = []
lastAction = []
situation = []
player_assisted = []

data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])            
        if key == 'shotType':
            shotType.append(data_home[index][key])            
        if key == 'minute':
            minute.append(data_home[index][key])            
        if key == 'lastAction':
            lastAction.append(data_home[index][key]) 
        if key == 'situation':
            situation.append(data_home[index][key])  
        if key == 'player_assisted':
            player_assisted.append(data_home[index][key])            

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])
        if key == 'shotType':
            shotType.append(data_away[index][key]) 
        if key == 'minute':
            minute.append(data_away[index][key])  
        if key == 'lastAction':
            lastAction.append(data_away[index][key])
        if key == 'situation':
            situation.append(data_away[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_away[index][key])

# %%
result
# Out:
# ['SavedShot',
#  'MissedShots',
#  'MissedShots',
#  'BlockedShot',
#  'SavedShot',
#  'Goal',
#  'Goal',
#  'BlockedShot',
#  'MissedShots',
#  'MissedShots',
#  'SavedShot',
#  'SavedShot',
#  'Goal',
#  'MissedShots',
#  'BlockedShot',
#  'SavedShot',
#  'BlockedShot',
#  'MissedShots',
#  'BlockedShot',
#  'MissedShots']

# %%
col_names = ['x','y','xg','team','player','shotType','result','minute','lastAction','situation','player_assisted']

df = pd.DataFrame([x,y,xG,team,player,shotType,result,minute,lastAction,situation,player_assisted], index = col_names)
df = df.T

# %%
df
# Out:
#                      x                    y                    xg      team  \
# 0   0.7240000152587891                 0.74  0.011110288091003895     Lazio
# 1    0.914000015258789    0.544000015258789   0.10795050859451294     Lazio
# 2                0.905   0.5270000076293946   0.06845464557409286     Lazio
# 3    0.725999984741211   0.5159999847412109  0.049644842743873596     Lazio
# 4   0.8859999847412109  0.35700000762939454   0.06794381886720657     Lazio
# 5   0.9419999694824219                0.445    0.4407545030117035     Lazio
# 6   0.8980000305175782    0.610999984741211    0.3509633243083954     Lazio
# 7   0.8090000152587891    0.524000015258789    0.0671779066324234     Lazio
# 8   0.9009999847412109                0.795   0.02330172434449196     Lazio
# 9   0.9259999847412109                0.455   0.12303689867258072  Juventus
# 10  0.9569999694824218                0.495   0.49779877066612244  Juventus
# 11  0.9819999694824219                0.505    0.9086103439331055  Juventus
# 12  0.9830000305175781    0.500999984741211    0.7469373941421509  Juventus
# 13               0.925                 0.51  0.060212355107069016  Juventus
# 14  0.9159999847412109                 0.61   0.07173343002796173  Juventus
# 15  0.9669999694824218   0.4979999923706055   0.22089095413684845  Juventus
# 16  0.8240000152587891  0.36400001525878906   0.04850884526968002  Juventus
# 17                0.89                 0.55   0.08446506410837173  Juventus
# 18  0.8719999694824219   0.4470000076293945   0.07510072737932205  Juventus
# 19  0.7980000305175782                0.675  0.022827008739113808  Juventus
#
#                      player   shotType       result minute lastAction  \
# 0              Luis Alberto  RightFoot    SavedShot      4       Pass
# 1   Sergej Milinkovic-Savic       Head  MissedShots      9      Cross
# 2   Sergej Milinkovic-Savic       Head  MissedShots     11      Cross
# 3   Sergej Milinkovic-Savic  RightFoot  BlockedShot     14   Standard
# 4             Ciro Immobile  RightFoot    SavedShot     28    Chipped
# 5   Sergej Milinkovic-Savic   LeftFoot         Goal     37      Cross
# 6           Mattia Zaccagni  RightFoot         Goal     52       Pass
# 7   Sergej Milinkovic-Savic  RightFoot  BlockedShot     59       Pass
# 8              Luis Alberto  RightFoot  MissedShots     68       Pass
# 9            Dusan Vlahovic       Head  MissedShots      6      Cross
# 10                   Bremer       Head    SavedShot     41      Cross
# 11            Adrien Rabiot   LeftFoot    SavedShot     41     Aerial
# 12            Adrien Rabiot       Head         Goal     41    Rebound
# 13           Dusan Vlahovic       Head  MissedShots     61     Aerial
# 14            Adrien Rabiot  RightFoot  BlockedShot     71       None
# 15          Arkadiusz Milik       Head    SavedShot     77       Foul
# 16           Nicolo Fagioli  RightFoot  BlockedShot     78       Pass
# 17           Nicolo Fagioli   LeftFoot  MissedShots     83      Cross
# 18           Ángel Di María   LeftFoot  BlockedShot     87      Cross
# 19          Leandro Paredes  RightFoot  MissedShots     88     TakeOn
#
#          situation  player_assisted
# 0         OpenPlay  Mattia Zaccagni
# 1         SetPiece     Luis Alberto
# 2       FromCorner     Luis Alberto
# 3   DirectFreekick             None
# 4         OpenPlay  Felipe Anderson
# 5         OpenPlay  Mattia Zaccagni
# 6         OpenPlay     Luis Alberto
# 7         OpenPlay    Ciro Immobile
# 8         SetPiece            Pedro
# 9         OpenPlay    Adrien Rabiot
# 10      FromCorner   Ángel Di María
# 11      FromCorner   Dusan Vlahovic
# 12      FromCorner             None
# 13        OpenPlay      Alex Sandro
# 14        OpenPlay             None
# 15      FromCorner  Leandro Paredes
# 16        OpenPlay    Adrien Rabiot
# 17        OpenPlay  Federico Chiesa
# 18        OpenPlay    Fabio Miretti
# 19      FromCorner    Adrien Rabiot

# %%
luis = df[df['player'] == 'Luis Alberto']
luis
# Out:
#                     x      y                    xg   team        player  \
# 0  0.7240000152587891   0.74  0.011110288091003895  Lazio  Luis Alberto
# 8  0.9009999847412109  0.795   0.02330172434449196  Lazio  Luis Alberto
#
#     shotType       result minute lastAction situation  player_assisted
# 0  RightFoot    SavedShot      4       Pass  OpenPlay  Mattia Zaccagni
# 8  RightFoot  MissedShots     68       Pass  SetPiece            Pedro

# %%
import matplotlib as plt
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch, VerticalPitch

# %%
pitch = VerticalPitch(half=True)
fig, ax = pitch.draw()
