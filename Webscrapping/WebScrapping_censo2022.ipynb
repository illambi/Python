# %% [markdown]
# # Desafio Webscraping Censo 2022 de Wikipedia

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://es.wikipedia.org/wiki/Censo_argentino_de_2022'

# %%
df = pd.read_html(url, header=0)
df
# Out:
# [       Censo Argentino de 2022  \
#  0                          NaN
#  1          Información general
#  2               Nombre oficial
#  3                        Lugar
#  4         Fecha de realización
#  5        Autoridad responsable
#  6           Datos de población
#  7                    Población
#  8          Población masculina
#  9           Población femenina
#  10                  Cronología
#  11                        2010
#  12  [editar datos en Wikidata]
#
#                              Censo Argentino de 2022.1  \
#  0                                                 NaN
#  1                                 Información general
#  2   Censo Nacional de Población, Hogares y Viviend...
#  3                                           Argentina
#  4                                          18 de mayo
#  5                                               INDEC
#  6                                  Datos de población
#  7                           46.044.703 hab. (+14,78%)
# ...

# %%
df2022 = df[1]
df2022
# Out:
#     posición                     Jurisdicción PoblaciónCenso 2010[5]​  \
# 0        1.0        Provincia de Buenos Aires         15.625.084 [6]​
# 1        2.0                          Córdoba               3.308.876
# 2        3.0                         Santa Fe               3.194.537
# 3        4.0  Ciudad Autónoma de Buenos Aires               2.890.151
# 4        5.0                          Mendoza               1.738.929
# 5        6.0                          Tucumán               1.448.188
# 6        7.0                            Salta               1.214.441
# 7        8.0                       Entre Ríos               1.235.994
# 8        9.0                         Misiones               1.101.593
# 9       10.0                       Corrientes                 992.595
# 10      11.0                            Chaco               1.055.259
# 11      12.0              Santiago del Estero                 874.006
# ...

# %%
df2022.shape
# Out:
# (25, 6)
